# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("New Microsoft Excel Worksheet.csv")

# %%
df

# %%
def stock_status(row):
    if row['Stoc'] < row['Prag_minim']:
        return "CRITIC"
    elif row['Stoc'] == row['Prag_minim']:
        return "low"
    else:
        return "OK"

# %%
df["Status"] = df.apply(stock_status,axis = 1)

# %%
df
# Out:
#           Ceaiuri  Stoc  Prag_minim  Status
# 0      Ceai verde     5           2      OK
# 1      Ceai negru     3           2      OK
# 2  Ceai de fructe     1           2  CRITIC

# %%
def color_status(val):
    if val == "CRITIC":
        return "background-color: #ff4d4d"   # roșu
    elif val == "LOW":
        return "background-color: #ffd24d"   # galben
    elif val == "OK":
        return "background-color: #85e085"   # verde

df.style.applymap(color_status, subset=["Status"])
# Out:
# C:\Users\damia\AppData\Local\Temp\ipykernel_23088\3123767678.py:9: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df.style.applymap(color_status, subset=["Status"])
# <style type="text/css">
# #T_b5850_row0_col3, #T_b5850_row1_col3 {
#   background-color: #85e085;
# }
# #T_b5850_row2_col3 {
#   background-color: #ff4d4d;
# }
# </style>
# <table id="T_b5850">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5850_level0_col0" class="col_heading level0 col0" >Ceaiuri</th>
#       <th id="T_b5850_level0_col1" class="col_heading level0 col1" >Stoc</th>
#       <th id="T_b5850_level0_col2" class="col_heading level0 col2" >Prag_minim</th>
#       <th id="T_b5850_level0_col3" class="col_heading level0 col3" >Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5850_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5850_row0_col0" class="data row0 col0" >Ceai verde</td>
# ...

# %%
tea_sold = "Ceai verde"
quantity = 1
df.loc[df["Ceaiuri"]==tea_sold,'Stoc'] += quantity
df["Status"] = df.apply(stock_status, axis=1)

df.style.applymap(color_status, subset=["Status"])
# Out:
# C:\Users\damia\AppData\Local\Temp\ipykernel_23088\2417334634.py:6: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df.style.applymap(color_status, subset=["Status"])
# <style type="text/css">
# #T_40300_row0_col3, #T_40300_row1_col3 {
#   background-color: #85e085;
# }
# #T_40300_row2_col3 {
#   background-color: #ff4d4d;
# }
# </style>
# <table id="T_40300">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40300_level0_col0" class="col_heading level0 col0" >Ceaiuri</th>
#       <th id="T_40300_level0_col1" class="col_heading level0 col1" >Stoc</th>
#       <th id="T_40300_level0_col2" class="col_heading level0 col2" >Prag_minim</th>
#       <th id="T_40300_level0_col3" class="col_heading level0 col3" >Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40300_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40300_row0_col0" class="data row0 col0" >Ceai verde</td>
# ...

# %%
# Out:
#           Ceaiuri  Stoc  Prag_minim  Status
# 0      Ceai verde     5           2      OK
# 1      Ceai negru     3           2      OK
# 2  Ceai de fructe     1           2  CRITIC
